# %%
sentence1 = "I love coding it make me so happy"
sentence2 = "I hate the school programme its make you stupid"
sentence3 = " Next year I will go to spain"

# %%
from textblob import TextBlob

sentiment_score_1 = TextBlob(sentence1)
print(sentiment_score_1.sentiment.polarity)

sentiment_score_2 = TextBlob(sentence2)
print(sentiment_score_2.sentiment.polarity)

sentiment_score_3 = TextBlob(sentence3)
print(sentiment_score_3.sentiment)
# Out:
# 0.65
# -0.8
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vader_sentiment = SentimentIntensityAnalyzer()

print(vader_sentiment.polarity_scores(sentence1))
print(vader_sentiment.polarity_scores(sentence2))
print(vader_sentiment.polarity_scores(sentence3))
# Out:
# {'neg': 0.0, 'neu': 0.402, 'pos': 0.598, 'compound': 0.8733}
# {'neg': 0.504, 'neu': 0.496, 'pos': 0.0, 'compound': -0.7964}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %% [raw]
#                 Pre-trained Transformer

# %%
import transformers
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis")

print(sentiment_pipeline(sentence1))
print(sentiment_pipeline(sentence2))
print(sentiment_pipeline(sentiment3))
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import transformers
#       2 from transformers import pipeline
# ----> 3 sentiment_pipeline = pipeline("sentiment-analysis")
#       5 print(sentiment_pipeline(sentence1))
#       6 print(sentiment_pipeline(sentence2))
#
# File ~\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:827, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     822         raise ValueError(
#     823             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#     824             " arguments might conflict, use only one.)"
#     825         )
#     826 if dtype is not None:
# --> 827     if isinstance(dtype, str) and hasattr(torch, dtype):
#     828         dtype = getattr(torch, dtype)
#     829     model_kwargs["dtype"] = dtype
#
# NameError: name 'torch' is not defined

# %%
# %pip install torch
